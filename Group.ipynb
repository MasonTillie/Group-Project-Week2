# %%
class Parking():
    def __init__(self):
        self.parking_spaces = 50
        self.tickets_availble = 50
        self.price30 = 5.99
        self.price60 = 10.99
        self.price90 = 13.99
        self.current_ticket = {'paid': 'false'}
        


    def take_ticket(self):
            print(f' There are {self.parking_spaces} parking spaces available')
            while self.parking_spaces >= 0:
                if self.parking_spaces == 0:
                    break
                ticket = int(input(f'The price for parking is ${self.price30} for 30 minutes, ${self.price60} for one hour, ${self.price90} for 90 minutes. (press #1 for 30 minutes, press #2 for one hour, press #3 for 90 minutes, press #4 to cancel.)' ))
                if ticket == 1:
                    print('Here is your ticket, it is valid for 30 minutes. Payment Code=111 (keep ticket for payment) ------')
                    self.parking_spaces -= 1
                    self.tickets_availble -= 1
                    break
                elif ticket == 2:
                    print('Here is your ticket, it is valid for one hour. Payment Code=222 (keep ticket for payment) ------')
                    self.parking_spaces -= 1
                    self.tickets_availble -= 1
                    break
                elif ticket == 3:
                    print('Here is your ticket, it is valid for 90 minutes. Payment Code=333 (keep ticket for payment) ------')
                    self.parking_spaces -= 1
                    self.tickets_availble -= 1
                    break
                elif ticket == 4:
                    print('please leave')
                    break
                else:
                    print('Invalid input')
                



    def leave_garage(self):
        leaving = int(input('What is your payment code?)'))
        if leaving == 111:
            self.current_ticket['paid'] = 'true' 
            print(f'You have been charged ${self.price30}.')
            print('You now have 15 minutes to leave, have a great day!')
            self.parking_spaces += 1
            self.tickets_availble += 1
        elif leaving == 222:
            self.current_ticket['paid'] = 'true'
            print(f'You have been charged ${self.price60}.')
            print('You now have 15 minutes to leave, have a great day!')
            self.parking_spaces += 1
            self.tickets_availble += 1
        elif leaving == 333:
            self.current_ticket['paid'] = 'true'
            print(f'You have been charged ${self.price90}.')
            print('You now have 15 minutes to leave, have a great day!')
            self.parking_spaces += 1
            self.tickets_availble += 1
        else:
            print('Invalid input')

   
    def space_info(self):
        print(f' There are {self.parking_spaces} parking spaces available')

car = Parking()

def runner():
    while True:
        user_choice = input('What would you like to do? (park, leave, or info )?').lower()
        if user_choice == 'leave':
            car.leave_garage()
            break  
        elif user_choice == 'park':
            car.take_ticket()
            break
        elif user_choice == 'info':
            car.space_info()
            break
        else:
           print('Not a valid option, please try again')
runner()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\masve\Downloads\CODING TEMPLE\Week 2\Group Project\Group-Project-Week2\Group.ipynb Cell 1 in <cell line: 85>()
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=82'>83</a>         else:
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=83'>84</a>            print('Not a valid option, please try again')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=84'>85</a> runner()
#
# c:\Users\masve\Downloads\CODING TEMPLE\Week 2\Group Project\Group-Project-Week2\Group.ipynb Cell 1 in runner()
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a> def runner():
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>     while True:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>         user_choice = input('What would you like to do? (park, leave, or info )?').lower()
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>         if user_choice == 'leave':
#      <a href='vscode-notebook-cell:/c%3A/Users/masve/Downloads/CODING%20TEMPLE/Week%202/Group%20Project/Group-Project-Week2/Group.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a>             car.leave_garage()
#
# File c:\Users\masve\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File c:\Users\masve\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
